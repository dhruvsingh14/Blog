# %% [markdown]
# Author: Dhruv Singh <br> Last Updated: 6.18.2025

# %% [markdown]
# ## Algorithmic Trading Strategies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import strategies as strat # strategies module
plt.style.use("seaborn-v0_8")

# %% [markdown]
# ##### IBKR Data Pull

# %%
from ib_async import *

# %%
# connecting to ibkr api
util.startLoop()
ib = IB()
ib.connect()
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1>

# %% [markdown]
# ##### EURUSD, Daily Data

# %%
# Parameters
symbol = "EURUSD"
bar_size = "1 day"          # e.g. "5 mins", "1 hour", "1 day"
end = "2025-06-15"
what_to_show = "MIDPOINT"   # alternatives: "TRADES", "ASK", etc.

# %%
# 1. Setup contract
contract = Forex(symbol)

# %%
# 2. Compute duration string
end_dt = pd.to_datetime(end)
duration_str = "20 Y"

# %%
# 3. Pull data
data = ib.reqHistoricalData(
    contract,
    endDateTime=end_dt.strftime("%Y%m%d %H:%M:%S"),
    durationStr=duration_str,
    barSizeSetting=bar_size,
    whatToShow=what_to_show,
    useRTH=True,
    formatDate=1
)

# %%
# 4. Convert to df
df = util.df(data)
df.set_index("date", inplace=True)
df.index = pd.to_datetime(df.index)
df = df.dropna()
df = df[["close"]].rename(columns={"close": "price"})
df["returns"] = np.log(df["price"] / df["price"].shift(1))
df = df.dropna()

# %%
# disconnecting
ib.disconnect()

# %%
# saving a copy of the data
#df.to_csv('data/eurusd_20yr.csv')

# %%
# reading data from local copy
#df = pd.read_csv('data/eurusd_20yr.csv')
#df.set_index("date", inplace=True)
#df.index = pd.to_datetime(df.index)

# %% [markdown]
# ## Strategy 1: SMA Crossover

# %%
# instantiating sma class
sma = strat.SMABacktester(df, 50, 200, "2005-06-15", "2025-06-15")

# %% [markdown]
# ### Backtesting

# %%
# performance over a 20-year period
cum_returns, outperf = sma.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 98.37%
# Outperformance vs. Benchmark: 2.26%

# %%
# displaying positions taken
sma.results
# Out:
#                price   returns  sma_short  sma_long  position  strategy  \
# date
# 2006-03-28  1.199950 -0.001291   1.201976  1.204475        -1  0.001291
# 2006-03-29  1.202400  0.002040   1.201799  1.204423        -1 -0.002040
# 2006-03-30  1.216700  0.011823   1.201939  1.204487        -1 -0.011823
# 2006-03-31  1.211750 -0.004077   1.201906  1.204500        -1  0.004077
# 2006-04-03  1.213875  0.001752   1.201572  1.204488        -1 -0.001752
# ...              ...       ...        ...       ...       ...       ...
# 2025-06-09  1.142080  0.002200   1.127020  1.082326         1  0.002200
# 2025-06-10  1.142420  0.000298   1.128282  1.082515         1  0.000298
# 2025-06-11  1.148755  0.005530   1.129552  1.082722         1  0.005530
# 2025-06-12  1.158355  0.008322   1.130615  1.082993         1  0.008322
# 2025-06-13  1.154705 -0.003156   1.131805  1.083225         1 -0.003156
#
#             creturns  cstrategy
# date
# 2006-03-28  0.998710   1.001292
# ...

# %%
# visualizing performance
sma.plot_results('EURUSD')

# %% [markdown]
# Recomputing with different parameters for SMA_S, SMA_L

# %%
# resetting parameters
sma.set_parameters(75, 150)

# %%
# performance over a 20-year period w/ new parameters
cum_returns, outperf = sma.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 154.16%
# Outperformance vs. Benchmark: 58.94%

# %%
# visualizing performance w/ new parameters
sma.plot_results('EURUSD')

# %% [markdown]
# #### Optimizing

# %%
# running combinations of SMA_S, SMA_L to select params with maximum cumulative returns
(opt_params, best_perf) = sma.optimize_parameters((25, 50, 1), # SMA_S
                                                  (100, 200, 1)) # SMA_L

# %%
sma_s, sma_l = opt_params
print(f"Optimal Parameters - SMA_S: {sma_s}, SMA_L: {sma_l}")
print(f"Best Cumulative Return: {best_perf:.2%}")
# Out:
# Optimal Parameters - SMA_S: 28, SMA_L: 158
# Best Cumulative Return: 238.39%

# %%
# best performance over 20-years, w/ optimal parameters
cum_returns, outperf = sma.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 238.39%
# Outperformance vs. Benchmark: 143.79%

# %%
# visualizing
sma.plot_results('EURUSD')

# %%
# performance of various SMA_S, SMA_L combinations
sma.results_overview
# Out:
#       SMA_S  SMA_L  performance
# 0        25    100     1.579140
# 1        25    101     1.489206
# 2        25    102     1.516210
# 3        25    103     1.615448
# 4        25    104     1.650626
# ...     ...    ...          ...
# 2495     49    195     1.014148
# 2496     49    196     1.005111
# 2497     49    197     0.993954
# 2498     49    198     0.963106
# 2499     49    199     0.992204
#
# [2500 rows x 3 columns]

# %% [markdown]
# ### Backtesting & Forward Testing

# %%
# backtesting on a subset: 75% of data
train = strat.SMABacktester(df, 50, 200, "2005-06-15", "2020-06-15")

# %%
# optimizing on a subset: 75% of data, and backtesting ("in-sample")
(opt_params, best_perf) = train.optimize_parameters((25, 50, 1), # SMA_S
                                                    (100, 200, 1)) # SMA_L

# %%
# optimal parameters
sma_s, sma_l = opt_params
print(f"Optimal Parameters - SMA_S: {sma_s}, SMA_L: {sma_l}")
print(f"Best Cumulative Return: {best_perf:.2%}")
# Out:
# Optimal Parameters - SMA_S: 44, SMA_L: 134
# Best Cumulative Return: 218.48%

# %%
# plotting results
train.plot_results('EURUSD')

# %%
# forward testing on remaining 25%
tester = strat.SMABacktester(df, 44, 134, "2020-06-15", "2025-06-15")

# %%
# forward testing performance of parameters, out-of-sample
cum_returns, outperf = tester.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 93.37%
# Outperformance vs. Benchmark: -0.75%

# %%
# over 5 year period, params underperform benchmark slightly
tester.plot_results('EURUSD') # may need more frequent readjustment

# %% [markdown]
# ## Strategy 2: Mean Reversion

# %%
# viewing raw dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5185 entries, 2005-06-21 to 2025-06-13
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    5185 non-null   float64
#  1   returns  5185 non-null   float64
# dtypes: float64(2)
# memory usage: 250.6 KB

# %% [markdown]
# ### Backtesting

# %%
# proportional transaction cost
ptc = 0.00007

# %%
# Instantiating the backtester
meanrev = strat.MeanRevBacktester(df, SMA=30, dev=2, tc=ptc, start="2005-06-15", end="2025-06-15")

# %%
# displaying the object
meanrev
# Out:
# MeanRevBacktester(SMA = 30, dev = 2, tc = 7e-05)

# %%
# performance over a 20-year period
cum_returns, outperf = meanrev.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 83.19%
# Outperformance vs. Benchmark: -11.61%

# %%
# displaying positions taken
meanrev.results
# Out:
#                price   returns       SMA     Lower     Upper  distance  \
# date
# 2005-08-02  1.219000  0.000821  1.206765  1.189734  1.223796  0.012235
# 2005-08-03  1.233700  0.011987  1.207462  1.187889  1.227035  0.026238
# 2005-08-04  1.238400  0.003802  1.208612  1.186075  1.231149  0.029788
# 2005-08-05  1.235900 -0.002021  1.209508  1.184865  1.234151  0.026392
# 2005-08-08  1.235200 -0.000567  1.210138  1.183865  1.236412  0.025062
# ...              ...       ...       ...       ...       ...       ...
# 2025-06-09  1.142080  0.002200  1.130915  1.112972  1.148858  0.011165
# 2025-06-10  1.142420  0.000298  1.131046  1.112820  1.149272  0.011374
# 2025-06-11  1.148755  0.005530  1.131575  1.112241  1.150910  0.017180
# 2025-06-12  1.158355  0.008322  1.132555  1.110926  1.154184  0.025800
# 2025-06-13  1.154705 -0.003156  1.133400  1.110354  1.156446  0.021305
#
#             position  strategy  trades  creturns  cstrategy
# date
# ...

# %%
# visualizing performance
meanrev.plot_results('EURUSD')

# %% [markdown]
# #### Optimizing

# %%
# running combinations of SMA and std. dev. to select params with maximum cumulative returns
(opt_params, best_perf) = meanrev.optimize_parameters((25, 100, 1), # SMA
                                                      (1, 5, 1)) # std. dev

# %%
sma, std_dev = opt_params
print(f"Optimal Parameters - SMA: {sma}, Std. Dev.: {std_dev}")
print(f"Best Cumulative Return: {best_perf:.2%}")
# Out:
# Optimal Parameters - SMA: 26, Std. Dev.: 3
# Best Cumulative Return: 127.76%

# %%
# best performance over 20-years, w/ optimal parameters
cum_returns, outperf = meanrev.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 127.76%
# Outperformance vs. Benchmark: 31.65%

# %%
# visualizing
meanrev.plot_results('EURUSD')

# %%
# positions taken
meanrev.results
# Out:
#                price   returns       SMA     Lower     Upper  distance  \
# date
# 2005-07-27  1.206600  0.004319  1.205379  1.180664  1.230093  0.001221
# 2005-07-28  1.213900  0.006032  1.205421  1.180580  1.230263  0.008479
# 2005-07-29  1.212200 -0.001401  1.205740  1.180603  1.230877  0.006460
# 2005-08-01  1.218000  0.004773  1.206087  1.179990  1.232183  0.011913
# 2005-08-02  1.219000  0.000821  1.206190  1.179669  1.232712  0.012810
# ...              ...       ...       ...       ...       ...       ...
# 2025-06-09  1.142080  0.002200  1.130683  1.102128  1.159239  0.011397
# 2025-06-10  1.142420  0.000298  1.131107  1.101728  1.160486  0.011313
# 2025-06-11  1.148755  0.005530  1.131560  1.100561  1.162559  0.017195
# 2025-06-12  1.158355  0.008322  1.132652  1.097905  1.167398  0.025703
# 2025-06-13  1.154705 -0.003156  1.133891  1.097409  1.170372  0.020814
#
#             position  strategy  trades  creturns  cstrategy
# date
# ...

# %%
# combinations of parameters vs. performance
meanrev.results_overview
# Out:
#      SMA  dev  performance
# 0     25    1     0.815168
# 1     25    2     0.826219
# 2     25    3     1.216784
# 3     25    4     1.000000
# 4     26    1     0.727278
# ..   ...  ...          ...
# 295   98    4     1.000000
# 296   99    1     0.713686
# 297   99    2     0.723119
# 298   99    3     0.992062
# 299   99    4     1.000000
#
# [300 rows x 3 columns]

# %%
# best performing combinations
meanrev.results_overview.nlargest(10, "performance")
# Out:
#     SMA  dev  performance
# 6    26    3     1.277628
# 2    25    3     1.216784
# 10   27    3     1.159474
# 14   28    3     1.140604
# 22   30    3     1.130334
# 34   33    3     1.114117
# 46   36    3     1.093544
# 26   31    3     1.092717
# 50   37    3     1.090746
# 18   29    3     1.089296

# %%
# worst performing combinations
meanrev.results_overview.nsmallest(10, "performance")
# Out:
#      SMA  dev  performance
# 165   66    2     0.627593
# 153   63    2     0.628334
# 157   64    2     0.631800
# 161   65    2     0.637614
# 65    41    2     0.646168
# 149   62    2     0.650331
# 185   71    2     0.650955
# 177   69    2     0.651563
# 69    42    2     0.655934
# 169   67    2     0.656062

# %% [markdown]
# ### Backtesting & Forward Testing

# %%
# backtesting on a subset: 75% of data
train = strat.MeanRevBacktester(df, SMA=30, dev=2, tc=ptc, start="2005-06-15", end="2020-06-15")

# %%
# optimizing on a subset: 75% of data, and backtesting ("in-sample")
(opt_params, best_perf) = train.optimize_parameters((25, 100, 1), # SMA
                                                    (1, 5, 1)) # std. dev

# %%
# optimal parameters
sma, std_dev = opt_params
print(f"Optimal Parameters - SMA: {sma}, Std. Dev.: {std_dev}")
print(f"Best Cumulative Return: {best_perf:.2%}")
# Out:
# Optimal Parameters - SMA: 26, Std. Dev.: 3
# Best Cumulative Return: 121.20%

# %%
# plotting results
train.plot_results('EURUSD')

# %%
# forward testing on remaining 25%
tester = strat.MeanRevBacktester(df, SMA=30, dev=2, tc=ptc, start="2020-06-15", end="2025-06-15")

# %%
# forward testing performance of parameters, out-of-sample
cum_returns, outperf = tester.test_strategy()
print(f"Cumulative Returns: {cum_returns:.2%}")
print(f"Outperformance vs. Benchmark: {outperf:.2%}")
# Out:
# Cumulative Returns: 106.76%
# Outperformance vs. Benchmark: 7.70%

# %%
# over 5 year period, params outperform benchmark slightly
tester.plot_results('EURUSD') # may need more frequent readjustment
